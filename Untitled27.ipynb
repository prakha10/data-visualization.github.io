# %% [markdown]
# <a href="https://colab.research.google.com/github/prakha10/data-visualization.github.io/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv')

# %%
df.price.plot.hist()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb15e7db10>,
# ...
#       dtype=object)

# %%
df.price.plot.hist(bins = 5)

# %%
df['price'].hist(by = df['neighbourhood_group'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb0b44fad0>,
# ...
#       dtype=object)
